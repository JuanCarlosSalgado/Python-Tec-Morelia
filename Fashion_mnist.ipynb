# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
mnist = tf.keras.datasets.fashion_mnist

# %%
(training_images, training_labels),(test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
training_images = training_images/255
test_images = test_images/255

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(128, activation= tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation= tf.nn.softmax)])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss = "sparse_categorical_crossentropy",
              metrics= ["accuracy"])

# %%
model.fit(training_images, training_labels, batch_size=100 , epochs=1)
# Out:
# 600/600 [==============================] - 4s 4ms/step - loss: 0.5444 - accuracy: 0.8126

# %%
model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4724 - accuracy: 0.8289
# [0.47244754433631897, 0.8288999795913696]

# %%
classifications = model.predict(test_images)
print(classifications[0])
# Out:
# [1.9251496e-05 6.2942017e-06 2.0298970e-05 9.2909486e-06 4.2286960e-05
#  1.3087954e-01 4.1783860e-05 2.0353666e-01 3.4392027e-03 6.6200542e-01]

# %%
print(test_labels[0])
# Out:
# 9

# %%
plt.imshow(test_images[0],cmap='gray_r')
plt.title('Actual Value: {}'.format(test_labels[0]))
prediction=model.predict(test_images)
plt.axis('off')
print('Predicted Value: ',np.argmax(prediction[0]))
if(test_labels[0]==(np.argmax(prediction[0]))):
  print('Successful prediction')
else:
  print('Unsuccessful prediction')
# Out:
# Predicted Value:  9
# Successful prediction

# %%
plt.imshow(test_images[7],cmap='gray_r')
plt.title('Actual Value: {}'.format(test_labels[7]))
prediction=model.predict(test_images)
plt.axis('off')
print('Predicted Value: ',np.argmax(prediction[7]))
if(test_labels[7]==(np.argmax(prediction[7]))):
  print('Successful prediction')
else:
  print('Unsuccessful prediction')
# Out:
# Predicted Value:  6
# Successful prediction

# %%
plt.imshow(test_images[12],cmap='gray_r')
plt.title('Actual Value: {}'.format(test_labels[12]))
prediction=model.predict(test_images)
plt.axis('off')
print('Predicted Value: ',np.argmax(prediction[12]))
if(test_labels[12]==(np.argmax(prediction[12]))):
  print('Successful prediction')
else:
  print('Unsuccessful prediction')
# Out:
# Predicted Value:  5
# Unsuccessful prediction
